# %%
import pandas as pd

# %%
df = pd.read_csv('taxi.csv.xz')

# %%
df.sample(5)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 484935         2  2018-05-02 16:38:44   2018-05-02 16:51:46                1
# 375233         2  2018-05-02 09:19:08   2018-05-02 09:27:26                2
# 483514         1  2018-05-02 16:24:16   2018-05-02 16:31:54                1
# 127031         2  2018-05-01 13:31:49   2018-05-01 13:59:32                1
# 157498         1  2018-05-01 15:33:32   2018-05-01 15:37:59                1
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 484935           1.67           1                  N           238
# 375233           0.95           1                  N           236
# 483514           0.70           1                  N           234
# 127031          10.10           1                  N           138
# 157498           0.70           1                  N           162
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 484935           263             2         10.0    1.0      0.5        0.00
# 375233           141             1          6.5    0.0      0.5        1.10
# 483514           113             1          6.5    1.0      0.5        1.65
# 127031           243             2         30.0    0.0      0.5        0.00
# 157498           162             2          5.0    0.0      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount
# 484935          0.00                    0.3         11.80
# 375233          0.00                    0.3          8.40
# 483514          0.00                    0.3          9.95
# 127031          5.76                    0.3         36.56
# 157498          0.00                    0.3          5.80

# %%
ndf = pd.DataFrame([
    (1, 'Creative'),
    (2, 'VeriFone'),
    (4, 'BigApple'),
], columns=['id', 'Vendor'])

# %%
ndf
# Out:
#    id    Vendor
# 0   1  Creative
# 1   2  VeriFone
# 2   4  BigApple

# %%
pd.merge(df, ndf, left_on='VendorID', right_on='id', how='left')
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2018-05-01 00:13:56   2018-05-01 00:22:46                1
# 1              1  2018-05-01 00:23:26   2018-05-01 00:29:56                1
# 2              1  2018-05-01 00:36:23   2018-05-01 00:48:26                2
# 3              1  2018-05-01 00:26:12   2018-05-01 00:27:05                1
# 4              1  2018-05-01 00:29:51   2018-05-01 00:30:02                1
# ...          ...                  ...                   ...              ...
# 499994         2  2018-05-02 17:27:40   2018-05-02 17:33:37                1
# 499995         2  2018-05-02 17:36:29   2018-05-02 17:48:23                1
# 499996         2  2018-05-02 17:56:43   2018-05-02 18:07:26                1
# 499997         2  2018-05-02 17:33:05   2018-05-02 18:38:26                1
# 499998         1  2018-05-02 17:19:21   2018-05-02 17:33:25                1
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                1.60           1                  N           230
# 1                1.70           1                  N           263
# 2                2.60           1                  N           239
# 3                0.00           1                  N           145
# 4                0.00           1                  N           145
# ...               ...         ...                ...           ...
# 499994           0.65           1                  N           233
# 499995           2.00           1                  N           229
# 499996           1.62           1                  N           137
# 499997          18.70           2                  N           132
# 499998           1.70           1                  N           236
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 50             1          8.0    0.5      0.5        1.85
# 1                239             1          7.5    0.5      0.5        2.00
# 2                152             1         12.0    0.5      0.5        1.00
# 3                145             1          2.5    0.5      0.5        9.63
# 4                145             2          2.5    0.5      0.5        0.00
# ...              ...           ...          ...    ...      ...         ...
# 499994           229             1          5.5    1.0      0.5        1.46
# 499995           224             1          9.5    1.0      0.5        2.26
# 499996             4             2          9.0    1.0      0.5        0.00
# 499997            50             1         52.0    4.5      0.5       12.61
# 499998           162             2         10.5    1.0      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount  id    Vendor
# 0               0.00                    0.3         11.15   1  Creative
# 1               0.00                    0.3         10.80   1  Creative
# 2               0.00                    0.3         14.30   1  Creative
# 3               0.00                    0.3         13.43   1  Creative
# 4               0.00                    0.3          3.80   1  Creative
# ...              ...                    ...           ...  ..       ...
# 499994          0.00                    0.3          8.76   2  VeriFone
# 499995          0.00                    0.3         13.56   2  VeriFone
# 499996          0.00                    0.3         10.80   2  VeriFone
# 499997          5.76                    0.3         75.67   2  VeriFone
# 499998          0.00                    0.3         12.30   1  Creative
#
# [499999 rows x 19 columns]

# %%
# %timeit pd.merge(df, ndf, left_on='VendorID', right_on='id', how='left')
# Out:
# 587 ms ± 55.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
ndfi = ndf.set_index('id')

# %%
# %timeit pd.merge(df, ndfi, left_on='VendorID', right_index=True, how='left')
# Out:
# 194 ms ± 13.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
587 / 194  # speed up by 3x
# Out:
# 3.0257731958762886

# %%
# merge and join faster working with index
