# %%
import pandas as pd

from bid_diff import median_diff

# %%
median_diff('bids.csv.xz')
# Out:
# 0.013655841283122139

# %%
# %prun -s cumulative median_diff('bids.csv.xz')
# sorted by cumulative time -> large amount of time in read_csv
# Out:
#          450557 function calls (450519 primitive calls) in 3.052 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    3.052    3.052 {built-in method builtins.exec}
#         1    0.000    0.000    3.052    3.052 <string>:1(<module>)
#         1    0.000    0.000    3.052    3.052 bid_diff.py:18(median_diff)
#         2    0.000    0.000    1.681    0.841 _decorators.py:302(wrapper)
#         1    0.000    0.000    1.681    1.681 readers.py:491(read_csv)
#         1    0.000    0.000    1.681    1.681 readers.py:467(_read)
#         1    0.000    0.000    1.655    1.655 readers.py:1045(read)
#         1    0.000    0.000    1.641    1.641 c_parser_wrapper.py:220(read)
#         1    0.506    0.506    1.635    1.635 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#         1    0.000    0.000    1.310    1.310 generic.py:217(apply)
# ...
